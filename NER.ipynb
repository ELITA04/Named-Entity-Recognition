# %%
import spacy
import random

# %%
cd /content/drive/My Drive/MachineLearning
# Out:
# /content/drive/My Drive/MachineLearning

# %%
with open('training.txt', 'r') as file:
    data = file.read().replace('\n', '')

# %%
print(data)
# Out:
# [('30 kg apples 90 rs 1 kg', {'entities': [(0, 5, 'weight'), (6, 13, 'product'), (13, 18, 'price')]}), ('70kg pears 60rs each kg', {'entities': [(0, 5, 'weight'), (5, 11, 'product'), (11, 16, 'price')]}), ('20 kg grapes 10rs kg', {'entities': [(0, 5, 'weight'), (6, 13, 'product'), (13, 17, 'price')]}), ('I want to sell 50kg of wheat for 400 rupees', {'entities': [(15, 19, 'weight'), (23, 29, 'product'), (33, 43, 'price')]}), ('Sell 60kg of rice 300 rupees', {'entities': [(13, 18, 'product'), (5, 10, 'weight'), (18, 28, 'price')]}), ('30 kg wheat 90rs each kg', {'entities': [(0, 5, 'weight'), (6, 12, 'product'), (12, 16, 'price')]}), ('30kg chickoo 10 rs per kg', {'entities': [(0, 4, 'weight'), (5, 13, 'product'), (13, 18, 'price')]}), ('30kg apples 90rs each kg', {'entities': [(0, 5, 'weight'), (12, 17, 'price'), (5, 12, 'weight')]}), ('I am charging 75 rupees per kg for melon', {'entities': [(14, 23, 'price'), (24, 30, 'weight'), (35, 40, 'product')]}), ('I have fresh carrots for 50
# ...

# %%
def train_spacy(data, iterations):
  nlp = spacy.blank('en')

  if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last = True)

  for _, annotations in TRAIN_DATA:
    for ent in annotations.get('entities'):
      list_item = list(ent)
      ner.add_label(list_item[2])
    
  pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
  with nlp.disable_pipes(*pipes):
    optimizer = nlp.begin_training()
    for item in range(20):
      print('Starting iteration ' + str(item))
      random.shuffle(TRAIN_DATA)
      losses = {}

      for text, annotation in TRAIN_DATA:
        nlp.update(
            [text],
            [annotations],
            drop = 0.2,
            losses = losses
        )
      print(losses)
  return nlp

# %%
training = train_spacy(data, 20)
# Out:
# Starting iteration 0
# {'ner': 5.642856635153294}
# Starting iteration 1
# {'ner': 5.525366738438606}
# Starting iteration 2
# {'ner': 5.396441332995892}
# Starting iteration 3
# {'ner': 5.133607525378466}
# Starting iteration 4
# {'ner': 4.737942337989807}
# Starting iteration 5
# {'ner': 4.415419347584248}
# Starting iteration 6
# {'ner': 3.8955638371407986}
# Starting iteration 7
# {'ner': 2.904622694477439}
# Starting iteration 8
# {'ner': 2.4262905158102512}
# Starting iteration 9
# {'ner': 2.2056257578078657}
# Starting iteration 10
# {'ner': 2.1851807564962655}
# Starting iteration 11
# {'ner': 2.05967523153231}
# Starting iteration 12
# {'ner': 1.949723027566506}
# Starting iteration 13
# {'ner': 1.4363291530899005}
# Starting iteration 14
# {'ner': 5.528556553845192}
# Starting iteration 15
# {'ner': 8.42339712381363}
# Starting iteration 16
# {'ner': 3.9111891854554415}
# Starting iteration 17
# {'ner': 3.9417775943875313}
# Starting iteration 18
# ...

# %%
test_text = input("Enter your testing text: ")
doc = training(test_text)
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Enter your testing text: 10rs rice 30kg
# 30kg 10 14 weight
